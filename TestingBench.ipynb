# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
points = [[1,2], [2,4], [4,5], [10,5]]
kmeans = KMeans(n_clusters=2)


x = kmeans.fit(points)
# Out:
# c:\Users\ashmi\scoop\apps\python\current\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter([i[0] for i in points], [i[1] for i in points], c=x.labels_)
x.cluster_centers_
# Out:
# array([[ 2.33333333,  3.66666667],
#        [10.        ,  5.        ]])
